# %% [markdown]
# <a href="https://colab.research.google.com/github/MridulSharma02/Deep-Learning-2025-26-Mridul-Sharma/blob/main/DL_Experiment_1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Manually Download Datasets

# %%
import pandas as pd

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-3f61a9bd-e6fe-45cc-8c78-65832b34fe0c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3f61a9bd-e6fe-45cc-8c78-65832b34fe0c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv('iris.csv')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Through Drive Import Datasets

# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/Heart_Disease_Prediction.csv")
df.head()
# Out:
#    Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   70    1                4  130          322             0            2
# 1   67    0                3  115          564             0            2
# 2   57    1                2  124          261             0            0
# 3   64    1                4  128          263             0            0
# 4   74    0                2  120          269             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     109                0            2.4            2
# 1     160                0            1.6            2
# 2     141                0            0.3            1
# 3     105                1            0.2            2
# 4     121                1            0.2            1
#
#    Number of vessels fluro  Thallium Heart Disease
# 0                        3         3      Presence
# 1                        0         7       Absence
# ...

# %%
pip install kagglehub[pandas-datasets]

# %%
import kagglehub
from kagglehub import KaggleDatasetAdapter

df = kagglehub.dataset_load(
    KaggleDatasetAdapter.PANDAS,
    "abidhussai512/gdp-and-consumption-per-capita",
    "Gross domestic product (GDP) and main components per capita (nama_10_pc).csv"
)

print(df.head())
# Out:
# Using Colab cache for faster access to the 'gdp-and-consumption-per-capita' dataset.
#   frq         unit na_itm   go   1995   1996   1997   1998   1999   2000  ...  \
# 0   A  CLV10_UR_HA    1GQ   AL   1370   1480   1310   1430   1620   1750  ...
# 1   A  CLV10_UR_HA    1GQ   AT  27450  28020  28590  29560  30610  31510  ...
# 2   A  CLV10_UR_HA    1GQ  NaN  26270  26560  27500  27980  28910  29910  ...
# 3   A  CLV10_UR_HA    1GQ    G   3240   3430   2960   3090   2850   2990  ...
# 4   A  CLV10_UR_HA    1GQ   CH  48350  48400  49270  50470  51050  52630  ...
#
#       2015     2016   2017   2018   2019   2020   2021   2022   2023   2024
# 0   3480.0   3620.0   3750   3890   3990   3880   4270   4530
# 1  35930.0  36230.0  36820  37550  38040  35480  37080  38620  37990  37550
# 2  34090.0  34320.0  34700  35190  35850  33990  35960  37090  37400  37580
# 3   5850.0   6110.0   6360   6600   6950   6800   7380   7730   7880   8160
# ...

# %% [markdown]
# Directly Use Dataset Through Kaggle

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("juhibhojani/house-price")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'house-price' dataset.
# Path to dataset files: /kaggle/input/house-price

# %% [markdown]
# Use Datasets Through Colab

# %%
import os
import kagglehub

path = kagglehub.dataset_download("timoboz/data-science-cheat-sheets")
print(path)
os.listdir(path)
# Out:
# Using Colab cache for faster access to the 'data-science-cheat-sheets' dataset.
# /kaggle/input/data-science-cheat-sheets
# ['Probability',
#  'Ordinary Differential Equations',
#  'Data Engineering',
#  'Data Science',
#  'DevOps',
#  'Artificial Intelligence',
#  'Git',
#  'README.md',
#  'Scala',
#  'Docker and Kubernetes',
#  'Excel',
#  'Data Warehouse',
#  'Python',
#  'Algorithms',
#  'Linux',
#  'Machine Learning',
#  'NLP',
#  'Deep Learning',
#  'Numpy',
#  'Images',
#  'Statistics',
#  'Mathematics',
#  'Interview Questions',
#  'SQL',
#  'CBAP.pdf',
#  'Matlab',
#  'R Cheat Sheet',
#  'Data Visualization',
#  'Pandas',
#  'Big Data',
#  'Data Mining']
